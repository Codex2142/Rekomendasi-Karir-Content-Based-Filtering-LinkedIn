# %% [markdown]
# # import Lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # set max column

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load

# %%
# Path dataset
DATA_PATH = "../dataset/raw/dump.csv"

# Load data
df = pd.read_csv(DATA_PATH)

# Tampilkan 5 data teratas
df.head()
# Out:
#    Unnamed: 0  ageEstimate  companyFollowerCount  \
# 0           0         41.0              198859.0
# 1           1         41.0              198859.0
# 2           2         41.0               10047.0
# 3           3         41.0              198859.0
# 4           4         30.0              300723.0
#
#                                companyHasLogo        companyName  \
# 0  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 1  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 2  b1c3fd9a-8f21-48f8-8321-d773b1ff3cb7-2.png            CommSec
# 3  5a92c12e-0a20-482b-95ec-e705a6294730-2.png  Commonwealth Bank
# 4  0f982557-a907-409e-af20-1feb0e0813cd-2.png             PayPal
#
#    companyStaffCount                   companyUrl           companyUrn  \
# 0            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# 1            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# 2              619.0    http://www.commsec.com.au  urn:li:company:2851
# 3            32905.0  http://www.commbank.com.au/  urn:li:company:2848
# 4            22522.0        http://www.paypal.com  urn:li:company:1482
#
#    connectionsCount country     endDate  followable  followersCount  \
# 0             500.0      au         NaN         1.0           506.0
# 1             500.0      au  2014-06-01         1.0           506.0
# 2             500.0      au  2012-12-01         1.0           506.0
# 3             500.0      au  2008-07-01         1.0           506.0
# 4             500.0      au         NaN         1.0           951.0
#
#   genderEstimate                                       hasPicture  isPremium  \
# 0           male                                              NaN        0.0
# 1           male                                              NaN        0.0
# 2           male                                              NaN        0.0
# 3           male                                              NaN        0.0
# 4         female  RTMZ0-46bTjK4V_MGFDG6i5g0yZmFp5oS0S9liWvpWg.jpg        0.0
#
#               mbrLocation             mbrLocationCode  \
# 0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 1  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 2  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 3  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 4  Sydney Area, Australia  urn:li:fs_region:(au,4910)
#
#                                    mbrTitle                memberUrn  \
# 0  Portfolio Executive at Commonwealth Bank   urn:li:member:10013136
# 1  Portfolio Executive at Commonwealth Bank   urn:li:member:10013136
# 2  Portfolio Executive at Commonwealth Bank   urn:li:member:10013136
# 3  Portfolio Executive at Commonwealth Bank   urn:li:member:10013136
# 4          Senior Marketing Manager, PayPal  urn:li:member:100186032
#
#          posLocation             posLocationCode                     posTitle  \
# 0                NaN                         NaN          Portfolio Executive
# 1  Sydney, Australia  urn:li:fs_region:(au,4910)  Solution Delivery Executive
# 2                NaN                         NaN              Project Manager
# 3                NaN                         NaN              Project Manager
# 4                NaN                         NaN     Senior Marketing Manager
#
#    positionId   startDate  avgMemberPosDuration  avgCompanyPosDuration
# 0    240345.0  2014-07-01              760.5000               989.9361
# 1    240346.0  2013-11-01              760.5000               989.9361
# 2    240348.0  2008-08-01              760.5000               747.2308
# 3    240350.0  2007-02-01              760.5000               989.9361
# 4    229893.0  2017-01-01              395.2857               683.3496

# %% [markdown]
# # Row vs COlumn

# %%
# Jumlah baris dan kolom
print("Jumlah baris :", df.shape[0])
print("Jumlah kolom :", df.shape[1])
# Out:
# Jumlah baris : 39537
# Jumlah kolom : 27

# %% [markdown]
# # Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39537 entries, 0 to 39536
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             39537 non-null  int64
#  1   ageEstimate            39537 non-null  float64
#  2   companyFollowerCount   38071 non-null  float64
#  3   companyHasLogo         36407 non-null  object
#  4   companyName            39535 non-null  object
#  5   companyStaffCount      38401 non-null  float64
#  6   companyUrl             37449 non-null  object
#  7   companyUrn             39537 non-null  object
#  8   connectionsCount       39537 non-null  float64
#  9   country                39537 non-null  object
#  10  endDate                30626 non-null  object
#  11  followable             39537 non-null  float64
#  12  followersCount         39537 non-null  float64
#  13  genderEstimate         35567 non-null  object
#  14  hasPicture             29601 non-null  object
#  15  isPremium              39537 non-null  float64
#  16  mbrLocation            39537 non-null  object
#  17  mbrLocationCode        39389 non-null  object
#  18  mbrTitle               39537 non-null  object
#  19  memberUrn              39537 non-null  object
#  20  posLocation            28411 non-null  object
#  21  posLocationCode        16967 non-null  object
#  22  posTitle               39537 non-null  object
#  23  positionId             39537 non-null  float64
#  24  startDate              39521 non-null  object
#  25  avgMemberPosDuration   39312 non-null  float64
#  26  avgCompanyPosDuration  38686 non-null  float64
# dtypes: float64(10), int64(1), object(16)
# memory usage: 8.1+ MB

# %% [markdown]
# # Daftar Nama Kolom

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'ageEstimate',
#  'companyFollowerCount',
#  'companyHasLogo',
#  'companyName',
#  'companyStaffCount',
#  'companyUrl',
#  'companyUrn',
#  'connectionsCount',
#  'country',
#  'endDate',
#  'followable',
#  'followersCount',
#  'genderEstimate',
#  'hasPicture',
#  'isPremium',
#  'mbrLocation',
#  'mbrLocationCode',
#  'mbrTitle',
#  'memberUrn',
#  'posLocation',
#  'posLocationCode',
#  'posTitle',
#  'positionId',
#  'startDate',
#  'avgMemberPosDuration',
#  'avgCompanyPosDuration']

# %% [markdown]
# # Statistik Deskriptif (Numerik)

# %%
df.describe()
# Out:
#          Unnamed: 0   ageEstimate  companyFollowerCount  companyStaffCount  \
# count  39537.000000  39537.000000          3.807100e+04       38401.000000
# mean   19768.000000     38.434251          2.141731e+05       20451.816177
# std    11413.493133      9.626035          6.942288e+05       67548.466022
# min        0.000000     20.000000          0.000000e+00           0.000000
# 25%     9884.000000     31.000000          1.490000e+03          97.000000
# 50%    19768.000000     38.000000          1.433100e+04        1270.000000
# 75%    29652.000000     45.000000          1.263610e+05        9808.000000
# max    39536.000000     86.000000          7.502740e+06      568533.000000
#
#        connectionsCount    followable  followersCount     isPremium  \
# count      39537.000000  39537.000000    39537.000000  39537.000000
# mean         424.573159      0.950199     1203.336925      0.130359
# std          123.317422      0.217537     2976.006298      0.336702
# min            0.000000      0.000000        0.000000      0.000000
# 25%          371.000000      1.000000      353.000000      0.000000
# 50%          500.000000      1.000000      654.000000      0.000000
# 75%          500.000000      1.000000     1191.000000      0.000000
# max          500.000000      1.000000   161922.000000      1.000000
#
#          positionId  avgMemberPosDuration  avgCompanyPosDuration
# count  3.953700e+04          39312.000000           38686.000000
# mean   2.987947e+06            875.186984             888.257529
# std    9.043136e+06            639.812201             331.099677
# min    2.200000e+01              0.000000             -91.000000
# 25%    1.732730e+05            502.125000             724.861300
# 50%    2.457850e+05            730.600000             897.069100
# 75%    3.008140e+05           1068.919650            1039.168300
# max    3.845443e+07          15492.500000            9497.000000

# %% [markdown]
# # Statistik Deskriptif (Kategorikal)

# %%
df.describe(include='object')
# Out:
#                                     companyHasLogo companyName  \
# count                                        36407       39535
# unique                                       11381       13755
# top     5de45a81-c722-428e-aa8e-a90867d0badb-2.png     Telstra
# freq                                           683         683
#
#                     companyUrl           companyUrn country     endDate  \
# count                    37449                39537   39537       30626
# unique                   12093                13783       1         417
# top     http://www.telstra.com  urn:li:company:1636      au  2015-12-01
# freq                       683                  683   39537         448
#
#        genderEstimate                                       hasPicture  \
# count           35567                                            29601
# unique              2                                             4860
# top              male  Pm54TkNdaEo426PHIrLhQiflArsXe-mF9yedQWZN99A.jpg
# freq            23834                                               69
#
#               mbrLocation             mbrLocationCode  \
# count               39537                       39389
# unique                474                         461
# top     Sydney, Australia  urn:li:fs_region:(au,4910)
# freq                 9023                       13811
#
#                                                  mbrTitle  \
# count                                               39537
# unique                                               6710
# top     National Coordinator - Website and Learning Ma...
# freq                                                   69
#
#                      memberUrn        posLocation             posLocationCode  \
# count                    39537              28411                       16967
# unique                    6853               5136                         345
# top     urn:li:member:51452257  Sydney, Australia  urn:li:fs_region:(au,4910)
# freq                        69               6586                        5963
#
#                posTitle   startDate
# count             39537       39521
# unique            23907         469
# top     Project Manager  2012-01-01
# freq                442         516

# %% [markdown]
# # Analisis Missing Value (Jumlah)

# %%
missing_count = df.isnull().sum().sort_values(ascending=False)

missing_count
# Out:
# posLocationCode          22570
# posLocation              11126
# hasPicture                9936
# endDate                   8911
# genderEstimate            3970
# companyHasLogo            3130
# companyUrl                2088
# companyFollowerCount      1466
# companyStaffCount         1136
# avgCompanyPosDuration      851
# avgMemberPosDuration       225
# mbrLocationCode            148
# startDate                   16
# companyName                  2
# country                      0
# Unnamed: 0                   0
# connectionsCount             0
# companyUrn                   0
# ageEstimate                  0
# mbrTitle                     0
# mbrLocation                  0
# isPremium                    0
# followable                   0
# followersCount               0
# memberUrn                    0
# posTitle                     0
# positionId                   0
# dtype: int64

# %% [markdown]
# # Persentase Missing Value

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent = missing_percent.sort_values(ascending=False)

missing_percent
# Out:
# posLocationCode          57.085768
# posLocation              28.140729
# hasPicture               25.130890
# endDate                  22.538382
# genderEstimate           10.041227
# companyHasLogo            7.916635
# companyUrl                5.281129
# companyFollowerCount      3.707919
# companyStaffCount         2.873258
# avgCompanyPosDuration     2.152414
# avgMemberPosDuration      0.569087
# mbrLocationCode           0.374333
# startDate                 0.040468
# companyName               0.005059
# country                   0.000000
# Unnamed: 0                0.000000
# connectionsCount          0.000000
# companyUrn                0.000000
# ageEstimate               0.000000
# mbrTitle                  0.000000
# mbrLocation               0.000000
# isPremium                 0.000000
# followable                0.000000
# followersCount            0.000000
# memberUrn                 0.000000
# posTitle                  0.000000
# positionId                0.000000
# dtype: float64

# %% [markdown]
# # Visualisasi Missing Value

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    x=missing_percent.index,
    y=missing_percent.values
)
plt.xticks(rotation=90)
plt.title("Persentase Missing Value per Fitur")
plt.ylabel("Persentase (%)")
plt.xlabel("Fitur")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Identifikasi Fitur Numerik

# %%
numeric_features = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_features
# Out:
# ['Unnamed: 0',
#  'ageEstimate',
#  'companyFollowerCount',
#  'companyStaffCount',
#  'connectionsCount',
#  'followable',
#  'followersCount',
#  'isPremium',
#  'positionId',
#  'avgMemberPosDuration',
#  'avgCompanyPosDuration']

# %% [markdown]
# # Distribusi Fitur Numerik

# %%
for col in numeric_features:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribusi {col}")
    plt.xlabel(col)
    plt.ylabel("Frekuensi")
    plt.tight_layout()
    plt.show()
