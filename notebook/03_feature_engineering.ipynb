# %%
import pandas as pd
import pickle

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from scipy.sparse import hstack

# %%
df = pd.read_csv("../dataset/cooked/cleaned_data.csv")
df.head()
# Out:
#    Unnamed: 0  ageEstimate  companyFollowerCount        companyName  \
# 0           0         41.0              198859.0  commonwealth bank
# 1           1         41.0              198859.0  commonwealth bank
# 2           2         41.0               10047.0            commsec
# 3           3         41.0              198859.0  commonwealth bank
# 4           4         30.0              300723.0             paypal
#
#    companyStaffCount  connectionsCount country     endDate  followersCount  \
# 0            32905.0             500.0      au         NaN           506.0
# 1            32905.0             500.0      au  2014-06-01           506.0
# 2              619.0             500.0      au  2012-12-01           506.0
# 3            32905.0             500.0      au  2008-07-01           506.0
# 4            22522.0             500.0      au         NaN           951.0
#
#    isPremium             mbrLocation             mbrLocationCode  \
# 0        0.0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 1        0.0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 2        0.0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 3        0.0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
# 4        0.0  Sydney Area, Australia  urn:li:fs_region:(au,4910)
#
#                                    mbrTitle        posLocation  \
# 0  portfolio executive at commonwealth bank                NaN
# 1  portfolio executive at commonwealth bank  sydney, australia
# 2  portfolio executive at commonwealth bank                NaN
# 3  portfolio executive at commonwealth bank                NaN
# 4          senior marketing manager, paypal                NaN
#
#               posLocationCode                     posTitle   startDate  \
# 0                         NaN          portfolio executive  2014-07-01
# 1  urn:li:fs_region:(au,4910)  solution delivery executive  2013-11-01
# 2                         NaN              project manager  2008-08-01
# 3                         NaN              project manager  2007-02-01
# 4                         NaN     senior marketing manager  2017-01-01
#
#    avgMemberPosDuration  avgCompanyPosDuration
# 0              760.5000               989.9361
# 1              760.5000               989.9361
# 2              760.5000               747.2308
# 3              760.5000               989.9361
# 4              395.2857               683.3496

# %%
text_cols = ["mbrTitle", "posTitle", "companyName", "posLocation"]

df[text_cols] = df[text_cols].fillna("").astype(str)

# %%
df["combined_text"] = (
    df["mbrTitle"] + " " +
    df["posTitle"] + " " +
    df["companyName"] + " " +
    df["posLocation"]
)

# %%
tfidf_vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words="english"
)

tfidf_matrix = tfidf_vectorizer.fit_transform(df["combined_text"])

# %%
numeric_cols = [
    "ageEstimate",
    "connectionsCount",
    "followersCount",
    "companyFollowerCount",
    "companyStaffCount",
    "avgMemberPosDuration",
    "avgCompanyPosDuration"
]

categorical_cols = [
    "Unnamed: 0",
    "ageEstimate",
    "companyFollowerCount",
    "companyName",
    "companyStaffCount",
    "connectionsCount",
    "country",
    "endDate",
    "followersCount",
    "isPremium",
    "mbrLocation",
    "mbrLocationCode",
    "mbrTitle",
    "posLocation",
    "posLocationCode",
    "posTitle",
    "startDate",
    "avgMemberPosDuration",
    "avgCompanyPosDuration"
]

scaler = MinMaxScaler()
numeric_features = scaler.fit_transform(df[numeric_cols])

# %%
encoder = OneHotEncoder(
    handle_unknown="ignore",
    sparse_output=True
)

categorical_features = encoder.fit_transform(df[categorical_cols])

# %%
final_features = hstack([
    tfidf_matrix,
    numeric_features,
    categorical_features
])

# %%
pickle.dump(
    tfidf_vectorizer,
    open("../dataset/cooked/tfidf_vectorizer.pkl", "wb")
)

pickle.dump(
    final_features,
    open("../dataset/cooked/tfidf_matrix.pkl", "wb")
)

# %%
with open("../dataset/cooked/tfidf_matrix.pkl", "wb") as f:
    pickle.dump(final_features, f)

# %%
with open("../dataset/cooked/tfidf_matrix.pkl", "rb") as f:
    final_features = pickle.load(f)

# %%
type(final_features)
# Out:
# scipy.sparse._coo.coo_matrix
